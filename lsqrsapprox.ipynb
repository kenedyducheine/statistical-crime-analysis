# %%
import numpy as np 
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
with open("credentials.txt", "r") as f:
    creds = f.read()
credentials = service_account.Credentials.from_service_account_file(creds)

client_id = bigquery.Client(project="crime-analysis-491817", credentials=credentials)

query = """
SELECT * 
FROM `bigquery-public-data.chicago_crime.crime`
LIMIT 100
"""

df = client_id.query(query).to_dataframe()
print(df.columns)
# Out:
# /Users/KenedyDucheine/myenv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['unique_key', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location'],
#       dtype='object')
